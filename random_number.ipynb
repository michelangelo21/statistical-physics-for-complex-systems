# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
k = 10_000
randnums = [np.random.rand() for _ in range(k)]
plt.hist(randnums, bins=20)
# Out:
# (array([493., 506., 496., 508., 485., 490., 508., 503., 494., 484., 526.,
#         518., 496., 489., 484., 506., 510., 454., 536., 514.]),
#  array([4.03584174e-05, 5.00331208e-02, 1.00025883e-01, 1.50018646e-01,
#         2.00011408e-01, 2.50004171e-01, 2.99996933e-01, 3.49989695e-01,
#         3.99982458e-01, 4.49975220e-01, 4.99967983e-01, 5.49960745e-01,
#         5.99953508e-01, 6.49946270e-01, 6.99939032e-01, 7.49931795e-01,
#         7.99924557e-01, 8.49917320e-01, 8.99910082e-01, 9.49902844e-01,
#         9.99895607e-01]),
#  <BarContainer object of 20 artists>)
