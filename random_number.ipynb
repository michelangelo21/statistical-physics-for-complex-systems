# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
k = 10_000
randnums = [np.random.rand() for _ in range(k)]

# %%
plt.hist(randnums)
# Out:
# (array([ 979., 1007.,  992.,  964., 1024., 1004.,  992., 1009.,  995.,
#         1034.]),
#  array([1.60732659e-05, 9.99964715e-02, 1.99976870e-01, 2.99957268e-01,
#         3.99937666e-01, 4.99918064e-01, 5.99898463e-01, 6.99878861e-01,
#         7.99859259e-01, 8.99839657e-01, 9.99820056e-01]),
#  <BarContainer object of 10 artists>)
